# %% [markdown]
# If Else statements in Python

# %%
x = 500
y = 100
if x > y:
    print("x is greater than y")
    if x != y:
        print("Not equal")
else:
    print("y is greater than x")
# Out:
# x is greater than y
# Not equal

# %%
10 % 3 #modulus operator. it actually gives us the remainder
# Out:
# 1

# %%
num = float(input("Enter any number: "))
if num%2 == 0:
    if num%5 == 0:
        print(num,"divisible by 5 and 2")
    else:
        print("No 1")
else:
    print("No 2")
# Out:
# Enter any number:  15
# No 2

# %%
num = float(input("Enter any number: "))
if num%2 == 0 and num%5 == 0:
    print(num,"divisible by 5 and 2")
else:
    print("No")
# Out:
# Enter any number:  13
# No

# %%
from IPython.display import Image #to import an image from file.
Image('electricity.png')

# %%
amount = 0
net_unit = float(input('Enter your unit value: '))
if net_unit <= 100:
    amount = o
elif net_unit > 100 and net_unit <= 200:
    amount = (net_unit - 100)*5
elif net_unit > 200:
    amount = ((net_unit - 200)*10) + 500
print('amount is', amount)
# Out:
# Enter your unit value:  350
# amount is 2000.0
